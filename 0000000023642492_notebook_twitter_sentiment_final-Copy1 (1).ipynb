# %%
import pandas as pd

# %%
df=pd.read_csv("0000000000002747_training_twitter_x_y_train.csv",delimiter=",")
df
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# ...                   ...               ...         ...
# 10975  569934458364813313           neutral    American
# 10976  568564006329434113          positive      United
# 10977  569643648910028801          negative  US Airways
# 10978  568864981917110272          negative  US Airways
# 10979  568929299350179840          negative      United
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN  ColeyGirouard                 NaN
# 1                        NaN  WalterFaddoul                 NaN
# 2                        NaN      LocalKyle                 NaN
# ...

# %%
df_tst=pd.read_csv("0000000000002747_test_twitter_x_test.csv",delimiter=",")
df_tst
# Out:
#                 tweet_id         airline airline_sentiment_gold  \
# 0     569682010270101504        American                    NaN
# 1     569608307184242688        American                    NaN
# 2     567879304593408001       Southwest                    NaN
# 3     569757651539660801      US Airways                    NaN
# 4     569900705852608513        American                    NaN
# ...                  ...             ...                    ...
# 3655  570304244001193984      US Airways                    NaN
# 3656  567847737061941249      US Airways                    NaN
# 3657  567823564167192576  Virgin America                    NaN
# 3658  570273819287531520        American                    NaN
# 3659  569341769114128386          United                    NaN
#
#                  name negativereason_gold  retweet_count  \
# 0            zsalim03                 NaN              0
# 1            sa_craig                 NaN              0
# ...

# %%
txt_test=list(df_tst["text"])
len(txt_test)
# Out:
# 3660

# %%
df.shape[1]
# Out:
# 12

# %%
txt=list(df["text"])
len(txt)
# Out:
# 10980

# %%
txt
# Out:
# ['@SouthwestAir I am scheduled for the morning, 2 days after the fact, yes..not sure why my evening flight was the only one Cancelled Flightled',
#  '@SouthwestAir seeing your workers time in and time out going above and beyond is why I love flying with you guys. Thank you!',
#  '@united Flew ORD to Miami and back and  had great crew, service on both legs. THANKS',
#  "@SouthwestAir @dultch97 that's horse radish 😤🐴",
#  '@united so our flight into ORD was delayed because of Air Force One, but the last flight to SBN is at 8:20, 5 mins from now we just landed.',
#  '@united Why did you load us in this flying sardine can if you knew the pilots were 2 hours Late Flight?? #incompetent beyond belief',
#  "@JetBlue that is a stock response. Delays not as frustrating as poor cust serv &amp; being told by 3 ppl to wait &amp; they'd come back but did not.",
#  "@JetBlue That'd be nice! Hoping to rack up enough miles to take a trip to Seattle and enjoy a perfect latte in the city of coffee.",
# ...

# %%
categories=df['airline_sentiment']

# %%
cat_list=list(categories)
cat_list
# Out:
# ['negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
# ...

# %%
cat=set(list(categories))
len(cat_list)
# Out:
# 10980

# %%
cat
# Out:
# {'negative', 'neutral', 'positive'}

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
document=[]
for i in range(0,df.shape[0]):
    word=word_tokenize(txt[i])
    document.append((word,cat_list[i]))

# %%
document[0]
# Out:
# (['@',
#   'SouthwestAir',
#   'I',
#   'am',
#   'scheduled',
#   'for',
#   'the',
#   'morning',
#   ',',
#   '2',
#   'days',
#   'after',
#   'the',
#   'fact',
#   ',',
#   'yes..not',
#   'sure',
#   'why',
#   'my',
#   'evening',
#   'flight',
#   'was',
#   'the',
#   'only',
#   'one',
#   'Cancelled',
#   'Flightled'],
#  'negative')

# %%
doc_test=[word_tokenize(word) for word in txt_test]
doc_test[0]
# Out:
# ['@',
#  'AmericanAir',
#  'In',
#  'car',
#  'gng',
#  'to',
#  'DFW',
#  '.',
#  'Pulled',
#  'over',
#  '1hr',
#  'ago',
#  '-',
#  'very',
#  'icy',
#  'roads',
#  '.',
#  'On-hold',
#  'with',
#  'AA',
#  'since',
#  '1hr',
#  '.',
#  'Ca',
#  "n't",
#  'reach',
#  'arpt',
#  'for',
#  'AA2450',
#  '.',
#  'Wat',
#  '2',
#  'do',
#  '?']

# %%
from nltk.corpus import stopwords
import string
stop_words=stopwords.words('english')
puncuation = list(string.punctuation)
stop_words=stop_words+puncuation

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
lemmatizer=WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADJ
        return wordnet.NOUN

# %% [markdown]
# #r

# %%
def clean_review(words):
    output=[]
    for w in words:
        if w.lower() not in stop_words:
            pos=pos_tag([w])
            clean_word= lemmatizer.lemmatize(w,pos=get_simple_pos(pos[0][1]))
            output.append(clean_word.lower())
    return output

# %%
documents=[(clean_review(doc),category) for doc,category in document]
documents[0]
# Out:
# (['southwestair',
#   'schedule',
#   'morning',
#   '2',
#   'day',
#   'fact',
#   'yes..not',
#   'sure',
#   'even',
#   'flight',
#   'one',
#   'cancelled',
#   'flightled'],
#  'negative')

# %%
doc_test_clean=[clean_review(doc) for doc in doc_test]

# %%
doc_test_clean[0]
# Out:
# ['americanair',
#  'car',
#  'gng',
#  'dfw',
#  'pulled',
#  '1hr',
#  'ago',
#  'icy',
#  'road',
#  'on-hold',
#  'aa',
#  'since',
#  '1hr',
#  'ca',
#  "n't",
#  'reach',
#  'arpt',
#  'aa2450',
#  'wat',
#  '2']

# %%
sentiment=[category for doc,category in documents]

# %%
y_train=sentiment

# %%
x_train = [" ".join(doc) for doc,category in documents]

# %%
x_test = [" ".join(doc) for doc in doc_test_clean]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect=CountVectorizer(max_features=3000,ngram_range=(1,2))

# %%
train_data = count_vect.fit_transform(x_train)

# %%
count_vect.get_feature_names()
# Out:
# ['00',
#  '000',
#  '000 mile',
#  '03',
#  '10',
#  '10 day',
#  '10 hour',
#  '10 hr',
#  '10 min',
#  '10 minute',
#  '100',
#  '1000',
#  '10pm',
#  '11',
#  '11 30',
#  '12',
#  '12 hour',
#  '13',
#  '130',
#  '14',
#  '140',
#  '15',
#  '15 min',
#  '15 minute',
#  '150',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1hr',
#  '1k',
#  '1st',
#  '1st class',
#  '1st flight',
#  '1st time',
#  '20',
#  '20 min',
#  '20 minute',
#  '200',
#  '200 fee',
#  '2015',
#  '21',
#  '22',
#  '23',
#  '24',
#  '24 hour',
#  '24 hr',
#  '24hrs',
#  '25',
#  '25 min',
#  '25 minute',
#  '26',
#  '27',
#  '28',
#  '2day',
#  '2hrs',
#  '2nd',
#  '2nd time',
#  '2x',
#  '30',
#  '30 flight',
#  '30 min',
#  '30 minute',
#  '300',
#  '30am',
#  '30pm',
#  '32',
#  '35',
#  '35 min',
#  '36',
#  '3am',
#  '3hrs',
#  '3rd',
#  '3rd time',
#  '40',
#  '40 min',
#  '40 minute',
#  '400',
#  '42',
#  '45',
#  '45 min',
#  '45 minute',
#  '48',
#  '4th',
#  '50',
#  '50 min',
#  '50 minute',
#  '500',
# ...

# %%
test_data=count_vect.transform(x_test)

# %%
from sklearn.svm import SVC

# %%
svc=SVC(C=260)

# %%
svc.fit(train_data,y_train)
# Out:
# C:\Users\rohat\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=260, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc.score(train_data,y_train)
# Out:
# 0.8638433515482696

# %%
y_pred=svc.predict(test_data)
y_pred
# Out:
# array(['negative', 'neutral', 'negative', ..., 'negative', 'positive',
#        'negative'], dtype='<U8')

# %%
import numpy as np

# %%
np.savetxt("pred_twitter_final.csv",y_pred,fmt='%s')
